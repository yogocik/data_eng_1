# %%
import pandas as pd
import datetime
import traceback
import typing
import os
import json
from numpy import nan
from IPython.display import display

# %%
# PARAMETERS
ts_mili = "MILISECOND"
ts_mikro = "MIKROSECOND"

breakdown_col = {
    "c": "data",
    "u": "set",
    "d": "set"
}

# CUSTOM FUNCTIONS
def convert_timestamp(ts:int,unit:str=ts_mili) -> datetime.datetime:
    if unit == ts_mikro:
        ts /= 1000
    try:
        return datetime.datetime.fromtimestamp(ts)
    except Exception as e:
        traceback.print_exc()


def get_list_of_json(dir:str) -> typing.List[dict]:
    return [json.load(open(os.path.join(dir,x))) for x in os.listdir(dir)]


def separate_update_create(data:typing.List[dict]) -> typing.Dict[str,typing.List[dict]]:
    separate_dict = {"c": [], "u":[], "d":[]}
    for x in data:
        separate_dict[x["op"]].append(x)
    return separate_dict    


def create_df(data:typing.Dict[str,typing.List[dict]], data_col:dict=breakdown_col, data_col_name:str="data") -> pd.DataFrame:
    df_collection = {}
    for key, val in data.items():
        if len(val) == 0:
            df_collection[key] = pd.DataFrame()
            continue
        raw_df = pd.DataFrame(val)
        break_df = pd.DataFrame(raw_df[data_col[key]].to_list())
        combine_df = pd.concat([raw_df,break_df], axis=1).reset_index(drop=True)
        combine_df.rename(columns={data_col[key]:data_col_name},inplace=True)
        df_collection[key] = combine_df
    final_df = pd.concat(list(df_collection.values()), axis=0).reset_index(drop=True)
    return final_df


def load_data(dir:str, timestamp_col:typing.Dict[str,str]={}) -> pd.DataFrame:
    print("Start working ", dir)
    list_of_json = get_list_of_json(dir)
    data_list = separate_update_create(list_of_json)
    final_data = create_df(data_list)
    if timestamp_col != {}:
        for col, unit in timestamp_col.items():
            final_data[col] = final_data[col].apply(lambda x:convert_timestamp(x,unit))
    # final_data.fillna(method="ffill", inplace=True)
    print("Done working ", dir)
    return final_data


def join_table(left_df:pd.DataFrame, right_df:pd.DataFrame, 
               left_on:str,right_on:str, how:str="inner",
               suffix:tuple=('_left', '_right')) -> pd.DataFrame:
    return pd.merge(left_df,right_df,left_on=left_on,right_on=right_on,how=how,suffixes=suffix)


def add_value(x:int,y:int)->int:
    if pd.isna(x) and pd.isna(y):
        return nan
    else:
        return (x if not pd.isna(x) else 0) + (y if not pd.isna(y) else 0)


def main():
    data_collection = {
        "cards": {
            "url": "data/cards/",
            "data": None
        },
        "accounts": {
            "url": "data/accounts/",
            "data": None
        },
        "savings": {
            "url": "data/savings_accounts/",
            "data": None
        }
    }
    for key, val in data_collection.items():
        data_collection[key]["data"] = load_data(val["url"],{"ts": ts_mikro})
    
    # Card self join
    create_df = data_collection["cards"]["data"][data_collection["cards"]["data"]["op"] == "c"]
    update_df = data_collection["cards"]["data"][data_collection["cards"]["data"]["op"] == "u"]
    self_update_df = join_table(update_df,create_df[["id","card_id","card_number"]],"id","id",how="left")
    self_update_df = self_update_df.loc[:, ~self_update_df.columns.isin(["card_id_left","card_number_left"])]
    self_update_df.rename(columns={"card_id_right":"card_id","card_number_right":"card_number"},inplace=True)
    # data_collection["cards"]["data"] = pd.concat([create_df,self_update_df],axis=0).reset_index(drop=True)
    data_collection["cards"]["data"] = pd.concat([create_df,self_update_df],axis=0).sort_values(
                                          by=["ts"],ascending=[True]).reset_index(
                                          drop=True)
    # data_collection["cards"]["data"].fillna(method="ffill", inplace=True)

    # Account self join
    create_df = data_collection["accounts"]["data"][data_collection["accounts"]["data"]["op"] == "c"]
    update_df = data_collection["accounts"]["data"][data_collection["accounts"]["data"]["op"] == "u"]
    self_update_df = join_table(update_df,create_df[["id","account_id"]],"id","id",how="left")
    self_update_df = self_update_df.loc[:, ~self_update_df.columns.isin(["account_id_left"])]
    self_update_df.rename(columns={"account_id_right":"account_id"},inplace=True)
    data_collection["accounts"]["data"] = pd.concat([create_df,self_update_df],axis=0).sort_values(
                                          by=["ts"],ascending=[True]).reset_index(
                                          drop=True)
    # data_collection["accounts"]["data"].fillna(method="ffill", inplace=True)

    
    # Saving self join
    create_df = data_collection["savings"]["data"][data_collection["savings"]["data"]["op"] == "c"]
    update_df = data_collection["savings"]["data"][data_collection["savings"]["data"]["op"] == "u"]
    self_update_df = join_table(update_df,create_df[["id","savings_account_id"]],"id","id",how="left")
    self_update_df = self_update_df.loc[:, ~self_update_df.columns.isin(["savings_account_id_left"])]
    self_update_df.rename(columns={"savings_account_id_right":"savings_account_id"},inplace=True)
    data_collection["savings"]["data"] = pd.concat([create_df,self_update_df],axis=0).sort_values(
                                         by=["ts"],ascending=[True]).reset_index(
                                         drop=True)
    # data_collection["savings"]["data"].fillna(method="ffill", inplace=True)

    # Complete historical denormalized tables
    denom_account_card_df = join_table(data_collection["accounts"]["data"], 
                                       data_collection["cards"]["data"],
                                       "card_id", "card_id","left",
                                       suffix=("_account","_card"))
    denom_final_df = join_table(denom_account_card_df, data_collection["savings"]["data"],
                                "savings_account_id", "savings_account_id","left",
                                suffix=("","_saving"))
    
    # return denom_final_df.sort_values(by=["ts_account","ts","ts_card"],ascending=[True, True, True]).reset_index(drop=True)
    denom_final_df["ts_transaction"] = denom_final_df.apply (
                                       lambda row: row["ts"] if not pd.isnull(row["ts"]) else row["ts_card"], 
                                       axis=1)

    # denom_final_df.sort_values(by=["ts_account","ts_transaction"],ascending=[True, True]).reset_index(drop=True)

    denom_final_df["transaction_val"] = denom_final_df.apply(lambda x:add_value(x["credit_used"],x["balance"]),axis=1)

    valid_transaction_df = denom_final_df[[
        "id_account","id_card","id","op_card","op","credit_used","balance",
        "transaction_val","ts_transaction"]][
            ~pd.isnull(denom_final_df["ts_transaction"]) & ~pd.isnull(denom_final_df["transaction_val"])].sort_values(
                by=["ts_transaction"],ascending=[True]).reset_index(drop=True)
    
    valid_transaction_df = valid_transaction_df[(valid_transaction_df["op_card"] == "u") | (valid_transaction_df["op"] == "u")].reset_index(drop=True)

    vol_transaction_df = valid_transaction_df.groupby(
        by=["ts_transaction"], axis=0,dropna=True)["id_account"].size().reset_index(name='transaction_count')
    # transaction_stamp_df = denom_final_df.sort_values(by=["ts_transaction"],
    #                                ascending=[True]).reset_index(
    #                                drop=True)[["ts_account", "ts", "ts_card","account_id"]]
    
    # vol_transaction_df = transaction_stamp_df.groupby(by=["ts_transaction"], axis=0,dropna=True)[
    #                                             "account_id"].size().reset_index(
    #                                              name='transaction_count')
    
    # transaction_value_df = denom_final_df[["id_account","id_card","id", "creadit_used","balance","ts_transaction"]]

    # return denom_final_df
    # return data_collection
    # Fill Unknown
    data_collection["accounts"]["data"].fillna(method="ffill",inplace=True)
    data_collection["savings"]["data"].fillna(method="ffill", inplace=True)
    data_collection["cards"]["data"].fillna(method="ffill",inplace=True)
    # denom_final_df.fillna(method="ffill", inplace=True)
    # denom_final_df.fillna(method="ffill",inplace=True)
    # valid_transaction_df.fillna(method="ffill",inplace=True)
    # vol_transaction_df.fillna(method="ffill",inplace=True)

    # Transaction data
    print("Accounts Table")
    display(data_collection["accounts"]["data"])
    print("Savings Account Table")
    display(data_collection["savings"]["data"])
    print("Cards Table")
    display(data_collection["cards"]["data"])
    print("Complete Denormalized Tables")
    display(denom_final_df)
    print("Transaction Tables")
    display(valid_transaction_df)
    display(vol_transaction_df)

# %%
data = main()
# data.sort_values(by=["ts_account","ts_transaction"],ascending=[True, True]).reset_index(drop=True)
# Out:
# Start working  data/cards/
# Done working  data/cards/
# Start working  data/accounts/
# Done working  data/accounts/
# Start working  data/savings_accounts/
# Done working  data/savings_accounts/
# Accounts Table
#            id op                  ts  \
# 0  a1globalid  c 2020-01-01 14:30:00
# 1  a1globalid  u 2020-01-01 15:00:00
# 2  a1globalid  u 2020-01-01 22:00:00
# 3  a1globalid  u 2020-01-01 23:00:00
# 4  a1globalid  u 2020-01-02 08:00:00
# 5  a1globalid  u 2020-01-15 16:01:00
# 6  a1globalid  u 2020-01-16 15:30:00
#
#                                                 data account_id     name  \
# 0  {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1                       {'phone_number': '87654321'}         a1  Anthony
# 2                      {'savings_account_id': 'sa1'}         a1  Anthony
# 3  {'address': 'Jakarta', 'email': 'anthony@anoth...         a1  Anthony
# 4                                  {'card_id': 'c1'}         a1  Anthony
# 5                                    {'card_id': ''}         a1  Anthony
# 6                                  {'card_id': 'c2'}         a1  Anthony
#
#     address phone_number                    email card_id savings_account_id
# 0  New York     12345678     anthony@somebank.com     NaN                NaN
# 1  New York     87654321     anthony@somebank.com     NaN                NaN
# 2  New York     87654321     anthony@somebank.com     NaN                sa1
# 3   Jakarta     87654321  anthony@anotherbank.com     NaN                sa1
# 4   Jakarta     87654321  anthony@anotherbank.com      c1                sa1
# 5   Jakarta     87654321  anthony@anotherbank.com                        sa1
# 6   Jakarta     87654321  anthony@anotherbank.com      c2                sa1
# Savings Account Table
#             id op                  ts  \
# 0  sa1globalid  c 2020-01-01 22:00:00
# 1  sa1globalid  u 2020-01-02 16:00:00
# 2  sa1globalid  u 2020-01-05 00:31:00
# 3  sa1globalid  u 2020-01-10 16:30:00
# 4  sa1globalid  u 2020-01-10 18:00:00
# 5  sa1globalid  u 2020-01-15 16:01:00
# 6  sa1globalid  u 2020-01-18 05:01:00
# 7  sa1globalid  u 2020-01-20 14:30:00
#
#                                                 data savings_account_id  \
# 0  {'savings_account_id': 'sa1', 'balance': 0, 'i...                sa1
# 1                                 {'balance': 15000}                sa1
# 2                     {'interest_rate_percent': 3.0}                sa1
# 3                                 {'balance': 40000}                sa1
# 4                                 {'balance': 21000}                sa1
# 5                     {'interest_rate_percent': 1.5}                sa1
# 6                     {'interest_rate_percent': 4.0}                sa1
# 7                                 {'balance': 33000}                sa1
#
#    balance  interest_rate_percent  status
# 0      0.0                    1.5  ACTIVE
# 1  15000.0                    1.5  ACTIVE
# 2  15000.0                    3.0  ACTIVE
# 3  40000.0                    3.0  ACTIVE
# 4  21000.0                    3.0  ACTIVE
# 5  21000.0                    1.5  ACTIVE
# 6  21000.0                    4.0  ACTIVE
# 7  33000.0                    4.0  ACTIVE
# Cards Table
#            id op                  ts  \
# 0  c1globalid  c 2020-01-02 08:00:00
# 1  c1globalid  u 2020-01-05 00:30:00
# 2  c1globalid  u 2020-01-06 19:30:00
# 3  c1globalid  u 2020-01-08 01:00:00
# 4  c1globalid  u 2020-01-10 18:00:00
# 5  c1globalid  u 2020-01-15 16:00:00
# 6  c2globalid  c 2020-01-16 15:30:00
# 7  c2globalid  u 2020-01-18 05:00:00
# 8  c2globalid  u 2020-01-18 22:30:00
#
#                                                 data card_id card_number  \
# 0  {'card_id': 'c1', 'card_number': '11112222', '...      c1    11112222
# 1                               {'status': 'ACTIVE'}      c1    11112222
# 2                             {'credit_used': 12000}      c1    11112222
# 3                             {'credit_used': 19000}      c1    11112222
# 4                                 {'credit_used': 0}      c1    11112222
# 5                               {'status': 'CLOSED'}      c1    11112222
# 6  {'card_id': 'c2', 'card_number': '12123434', '...      c2    12123434
# 7                               {'status': 'ACTIVE'}      c2    12123434
# 8                             {'credit_used': 37000}      c2    12123434
#
#    credit_used  monthly_limit   status
# 0          0.0        30000.0  PENDING
# 1          0.0        30000.0   ACTIVE
# 2      12000.0        30000.0   ACTIVE
# 3      19000.0        30000.0   ACTIVE
# 4          0.0        30000.0   ACTIVE
# 5          0.0        30000.0   CLOSED
# 6          0.0        70000.0  PENDING
# 7          0.0        70000.0   ACTIVE
# 8      37000.0        70000.0   ACTIVE
# Complete Denormalized Tables
#     id_account op_account          ts_account  \
# 0   a1globalid          c 2020-01-01 14:30:00
# 1   a1globalid          u 2020-01-01 15:00:00
# 2   a1globalid          u 2020-01-01 22:00:00
# 3   a1globalid          u 2020-01-01 22:00:00
# 4   a1globalid          u 2020-01-01 22:00:00
# 5   a1globalid          u 2020-01-01 22:00:00
# 6   a1globalid          u 2020-01-01 22:00:00
# 7   a1globalid          u 2020-01-01 22:00:00
# 8   a1globalid          u 2020-01-01 22:00:00
# 9   a1globalid          u 2020-01-01 22:00:00
# 10  a1globalid          u 2020-01-01 23:00:00
# 11  a1globalid          u 2020-01-02 08:00:00
# 12  a1globalid          u 2020-01-02 08:00:00
# 13  a1globalid          u 2020-01-02 08:00:00
# 14  a1globalid          u 2020-01-02 08:00:00
# 15  a1globalid          u 2020-01-02 08:00:00
# 16  a1globalid          u 2020-01-02 08:00:00
# 17  a1globalid          u 2020-01-15 16:01:00
# 18  a1globalid          u 2020-01-16 15:30:00
# 19  a1globalid          u 2020-01-16 15:30:00
# 20  a1globalid          u 2020-01-16 15:30:00
#
#                                          data_account account_id     name  \
# 0   {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1                        {'phone_number': '87654321'}         a1      NaN
# 2                       {'savings_account_id': 'sa1'}         a1      NaN
# 3                       {'savings_account_id': 'sa1'}         a1      NaN
# 4                       {'savings_account_id': 'sa1'}         a1      NaN
# 5                       {'savings_account_id': 'sa1'}         a1      NaN
# 6                       {'savings_account_id': 'sa1'}         a1      NaN
# 7                       {'savings_account_id': 'sa1'}         a1      NaN
# 8                       {'savings_account_id': 'sa1'}         a1      NaN
# 9                       {'savings_account_id': 'sa1'}         a1      NaN
# 10  {'address': 'Jakarta', 'email': 'anthony@anoth...         a1      NaN
# 11                                  {'card_id': 'c1'}         a1      NaN
# 12                                  {'card_id': 'c1'}         a1      NaN
# 13                                  {'card_id': 'c1'}         a1      NaN
# 14                                  {'card_id': 'c1'}         a1      NaN
# 15                                  {'card_id': 'c1'}         a1      NaN
# 16                                  {'card_id': 'c1'}         a1      NaN
# 17                                    {'card_id': ''}         a1      NaN
# 18                                  {'card_id': 'c2'}         a1      NaN
# 19                                  {'card_id': 'c2'}         a1      NaN
# 20                                  {'card_id': 'c2'}         a1      NaN
#
#      address phone_number                    email card_id  ...   status  \
# 0   New York     12345678     anthony@somebank.com     NaN  ...      NaN
# 1        NaN     87654321                      NaN     NaN  ...      NaN
# 2        NaN          NaN                      NaN     NaN  ...      NaN
# 3        NaN          NaN                      NaN     NaN  ...      NaN
# 4        NaN          NaN                      NaN     NaN  ...      NaN
# 5        NaN          NaN                      NaN     NaN  ...      NaN
# 6        NaN          NaN                      NaN     NaN  ...      NaN
# 7        NaN          NaN                      NaN     NaN  ...      NaN
# 8        NaN          NaN                      NaN     NaN  ...      NaN
# 9        NaN          NaN                      NaN     NaN  ...      NaN
# 10   Jakarta          NaN  anthony@anotherbank.com     NaN  ...      NaN
# 11       NaN          NaN                      NaN      c1  ...  PENDING
# 12       NaN          NaN                      NaN      c1  ...   ACTIVE
# 13       NaN          NaN                      NaN      c1  ...      NaN
# 14       NaN          NaN                      NaN      c1  ...      NaN
# 15       NaN          NaN                      NaN      c1  ...      NaN
# 16       NaN          NaN                      NaN      c1  ...   CLOSED
# 17       NaN          NaN                      NaN          ...      NaN
# 18       NaN          NaN                      NaN      c2  ...  PENDING
# 19       NaN          NaN                      NaN      c2  ...   ACTIVE
# 20       NaN          NaN                      NaN      c2  ...      NaN
#
#              id   op                  ts  \
# 0           NaN  NaN                 NaT
# 1           NaN  NaN                 NaT
# 2   sa1globalid    c 2020-01-01 22:00:00
# 3   sa1globalid    u 2020-01-02 16:00:00
# 4   sa1globalid    u 2020-01-05 00:31:00
# 5   sa1globalid    u 2020-01-10 16:30:00
# 6   sa1globalid    u 2020-01-10 18:00:00
# 7   sa1globalid    u 2020-01-15 16:01:00
# 8   sa1globalid    u 2020-01-18 05:01:00
# 9   sa1globalid    u 2020-01-20 14:30:00
# 10          NaN  NaN                 NaT
# 11          NaN  NaN                 NaT
# 12          NaN  NaN                 NaT
# 13          NaN  NaN                 NaT
# 14          NaN  NaN                 NaT
# 15          NaN  NaN                 NaT
# 16          NaN  NaN                 NaT
# 17          NaN  NaN                 NaT
# 18          NaN  NaN                 NaT
# 19          NaN  NaN                 NaT
# 20          NaN  NaN                 NaT
#
#                                                  data  balance  \
# 0                                                 NaN      NaN
# 1                                                 NaN      NaN
# 2   {'savings_account_id': 'sa1', 'balance': 0, 'i...      0.0
# 3                                  {'balance': 15000}  15000.0
# 4                      {'interest_rate_percent': 3.0}      NaN
# 5                                  {'balance': 40000}  40000.0
# 6                                  {'balance': 21000}  21000.0
# 7                      {'interest_rate_percent': 1.5}      NaN
# 8                      {'interest_rate_percent': 4.0}      NaN
# 9                                  {'balance': 33000}  33000.0
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
#
#     interest_rate_percent  status_saving      ts_transaction transaction_val
# 0                     NaN            NaN                 NaT             NaN
# 1                     NaN            NaN                 NaT             NaN
# 2                     1.5         ACTIVE 2020-01-01 22:00:00             0.0
# 3                     NaN            NaN 2020-01-02 16:00:00         15000.0
# 4                     3.0            NaN 2020-01-05 00:31:00             NaN
# 5                     NaN            NaN 2020-01-10 16:30:00         40000.0
# 6                     NaN            NaN 2020-01-10 18:00:00         21000.0
# 7                     1.5            NaN 2020-01-15 16:01:00             NaN
# 8                     4.0            NaN 2020-01-18 05:01:00             NaN
# 9                     NaN            NaN 2020-01-20 14:30:00         33000.0
# 10                    NaN            NaN                 NaT             NaN
# 11                    NaN            NaN 2020-01-02 08:00:00             0.0
# 12                    NaN            NaN 2020-01-05 00:30:00             NaN
# 13                    NaN            NaN 2020-01-06 19:30:00         12000.0
# 14                    NaN            NaN 2020-01-08 01:00:00         19000.0
# 15                    NaN            NaN 2020-01-10 18:00:00             0.0
# 16                    NaN            NaN 2020-01-15 16:00:00             NaN
# 17                    NaN            NaN                 NaT             NaN
# 18                    NaN            NaN 2020-01-16 15:30:00             0.0
# 19                    NaN            NaN 2020-01-18 05:00:00             NaN
# 20                    NaN            NaN 2020-01-18 22:30:00         37000.0
#
# [21 rows x 28 columns]
# Transaction Tables
#    id_account     id_card           id op_card   op  credit_used  balance  \
# 0  a1globalid         NaN  sa1globalid     NaN    u          NaN  15000.0
# 1  a1globalid  c1globalid          NaN       u  NaN      12000.0      NaN
# 2  a1globalid  c1globalid          NaN       u  NaN      19000.0      NaN
# 3  a1globalid         NaN  sa1globalid     NaN    u          NaN  40000.0
# 4  a1globalid         NaN  sa1globalid     NaN    u          NaN  21000.0
# 5  a1globalid  c1globalid          NaN       u  NaN          0.0      NaN
# 6  a1globalid  c2globalid          NaN       u  NaN      37000.0      NaN
# 7  a1globalid         NaN  sa1globalid     NaN    u          NaN  33000.0
#
#    transaction_val      ts_transaction
# 0          15000.0 2020-01-02 16:00:00
# 1          12000.0 2020-01-06 19:30:00
# 2          19000.0 2020-01-08 01:00:00
# 3          40000.0 2020-01-10 16:30:00
# 4          21000.0 2020-01-10 18:00:00
# 5              0.0 2020-01-10 18:00:00
# 6          37000.0 2020-01-18 22:30:00
# 7          33000.0 2020-01-20 14:30:00
#        ts_transaction  transaction_count
# 0 2020-01-02 16:00:00                  1
# 1 2020-01-06 19:30:00                  1
# 2 2020-01-08 01:00:00                  1
# 3 2020-01-10 16:30:00                  1
# 4 2020-01-10 18:00:00                  2
# 5 2020-01-18 22:30:00                  1
# 6 2020-01-20 14:30:00                  1

# %%
data.columns
# Out:
# Index(['id_account', 'op_account', 'ts_account', 'data_account', 'account_id',
#        'name', 'address', 'phone_number', 'email', 'card_id',
#        'savings_account_id', 'id_card', 'op_card', 'ts_card', 'data_card',
#        'card_number', 'credit_used', 'monthly_limit', 'status', 'id', 'op',
#        'ts', 'data', 'balance', 'interest_rate_percent', 'status_saving',
#        'ts_transaction'],
#       dtype='object')

# %%
valid_transaction = data[["id_account","id_card","id", "credit_used","balance","transaction_val","ts_transaction"]][~pd.isnull(data["ts_transaction"]) & ~pd.isnull(data["transaction_val"])].sort_values(by=["ts_transaction"],ascending=[True]).reset_index(drop=True)

# %%
valid_transaction
# Out:
#     id_account     id_card           id  credit_used  balance  \
# 0   a1globalid         NaN  sa1globalid          NaN      0.0
# 1   a1globalid  c1globalid          NaN          0.0      NaN
# 2   a1globalid         NaN  sa1globalid          NaN  15000.0
# 3   a1globalid  c1globalid          NaN      12000.0      NaN
# 4   a1globalid  c1globalid          NaN      19000.0      NaN
# 5   a1globalid         NaN  sa1globalid          NaN  40000.0
# 6   a1globalid         NaN  sa1globalid          NaN  21000.0
# 7   a1globalid  c1globalid          NaN          0.0      NaN
# 8   a1globalid  c2globalid          NaN          0.0      NaN
# 9   a1globalid  c2globalid          NaN      37000.0      NaN
# 10  a1globalid         NaN  sa1globalid          NaN  33000.0
#
#     transaction_val      ts_transaction
# 0               0.0 2020-01-01 22:00:00
# 1               0.0 2020-01-02 08:00:00
# 2           15000.0 2020-01-02 16:00:00
# 3           12000.0 2020-01-06 19:30:00
# 4           19000.0 2020-01-08 01:00:00
# 5           40000.0 2020-01-10 16:30:00
# 6           21000.0 2020-01-10 18:00:00
# 7               0.0 2020-01-10 18:00:00
# 8               0.0 2020-01-16 15:30:00
# 9           37000.0 2020-01-18 22:30:00
# 10          33000.0 2020-01-20 14:30:00

# %%
vol_transact = valid_transaction.groupby(by=["ts_transaction"], axis=0,dropna=True)["id_account"].size().reset_index(name='transaction_count')

# %%
vol_transact
# Out:
#        ts_transaction  transaction_count
# 0 2020-01-01 22:00:00                  1
# 1 2020-01-02 08:00:00                  1
# 2 2020-01-02 16:00:00                  1
# 3 2020-01-06 19:30:00                  1
# 4 2020-01-08 01:00:00                  1
# 5 2020-01-10 16:30:00                  1
# 6 2020-01-10 18:00:00                  2
# 7 2020-01-16 15:30:00                  1
# 8 2020-01-18 22:30:00                  1
# 9 2020-01-20 14:30:00                  1

# %%
def add_value(x:int,y:int)->int:
    if pd.isna(x) and pd.isna(y):
        return np.nan
    else:
        return (x if not pd.isna(x) else 0) + (y if not pd.isna(y) else 0)

# data["transaction_val"] = data.apply(lambda x:(x["credit_used"] if not pd.isna(x["credit_used"]) else 0) + 
#                                     (x["balance"] if not pd.isna(x["balance"]) else 0),axis=1)
data["transaction_val"] = data.apply(lambda x:add_value(x["credit_used"],x["balance"]),axis=1)

# %%
data.to_excel("denom_final.xlsx")

# %%
transaction = data.sort_values(by=["ts_transaction"],ascending=[True]).reset_index(drop=True)[["ts_account", "ts", "ts_card","ts_transaction","data_account","data_card","data","account_id"]]

# %%
transaction
# Out:
#             ts_account                  ts             ts_card  \
# 0  2020-01-01 22:00:00 2020-01-01 22:00:00                 NaT
# 1  2020-01-02 08:00:00                 NaT 2020-01-02 08:00:00
# 2  2020-01-01 22:00:00 2020-01-02 16:00:00                 NaT
# 3  2020-01-02 08:00:00                 NaT 2020-01-05 00:30:00
# 4  2020-01-01 22:00:00 2020-01-05 00:31:00                 NaT
# 5  2020-01-02 08:00:00                 NaT 2020-01-06 19:30:00
# 6  2020-01-02 08:00:00                 NaT 2020-01-08 01:00:00
# 7  2020-01-01 22:00:00 2020-01-10 16:30:00                 NaT
# 8  2020-01-01 22:00:00 2020-01-10 18:00:00                 NaT
# 9  2020-01-02 08:00:00                 NaT 2020-01-10 18:00:00
# 10 2020-01-02 08:00:00                 NaT 2020-01-15 16:00:00
# 11 2020-01-01 22:00:00 2020-01-15 16:01:00                 NaT
# 12 2020-01-16 15:30:00                 NaT 2020-01-16 15:30:00
# 13 2020-01-16 15:30:00                 NaT 2020-01-18 05:00:00
# 14 2020-01-01 22:00:00 2020-01-18 05:01:00                 NaT
# 15 2020-01-16 15:30:00                 NaT 2020-01-18 22:30:00
# 16 2020-01-01 22:00:00 2020-01-20 14:30:00                 NaT
# 17 2020-01-01 14:30:00                 NaT                 NaT
# 18 2020-01-01 15:00:00                 NaT                 NaT
# 19 2020-01-01 23:00:00                 NaT                 NaT
# 20 2020-01-15 16:01:00                 NaT                 NaT
#
#         ts_transaction                                       data_account  \
# 0  2020-01-01 22:00:00                      {'savings_account_id': 'sa1'}
# 1  2020-01-02 08:00:00                                  {'card_id': 'c1'}
# 2  2020-01-02 16:00:00                      {'savings_account_id': 'sa1'}
# 3  2020-01-05 00:30:00                                  {'card_id': 'c1'}
# 4  2020-01-05 00:31:00                      {'savings_account_id': 'sa1'}
# 5  2020-01-06 19:30:00                                  {'card_id': 'c1'}
# 6  2020-01-08 01:00:00                                  {'card_id': 'c1'}
# 7  2020-01-10 16:30:00                      {'savings_account_id': 'sa1'}
# 8  2020-01-10 18:00:00                      {'savings_account_id': 'sa1'}
# 9  2020-01-10 18:00:00                                  {'card_id': 'c1'}
# 10 2020-01-15 16:00:00                                  {'card_id': 'c1'}
# 11 2020-01-15 16:01:00                      {'savings_account_id': 'sa1'}
# 12 2020-01-16 15:30:00                                  {'card_id': 'c2'}
# 13 2020-01-18 05:00:00                                  {'card_id': 'c2'}
# 14 2020-01-18 05:01:00                      {'savings_account_id': 'sa1'}
# 15 2020-01-18 22:30:00                                  {'card_id': 'c2'}
# 16 2020-01-20 14:30:00                      {'savings_account_id': 'sa1'}
# 17                 NaT  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 18                 NaT                       {'phone_number': '87654321'}
# 19                 NaT  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 20                 NaT                                    {'card_id': ''}
#
#                                             data_card  \
# 0                                                 NaN
# 1   {'card_id': 'c1', 'card_number': '11112222', '...
# 2                                                 NaN
# 3                                {'status': 'ACTIVE'}
# 4                                                 NaN
# 5                              {'credit_used': 12000}
# 6                              {'credit_used': 19000}
# 7                                                 NaN
# 8                                                 NaN
# 9                                  {'credit_used': 0}
# 10                               {'status': 'CLOSED'}
# 11                                                NaN
# 12  {'card_id': 'c2', 'card_number': '12123434', '...
# 13                               {'status': 'ACTIVE'}
# 14                                                NaN
# 15                             {'credit_used': 37000}
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                  data account_id
# 0   {'savings_account_id': 'sa1', 'balance': 0, 'i...         a1
# 1                                                 NaN         a1
# 2                                  {'balance': 15000}         a1
# 3                                                 NaN         a1
# 4                      {'interest_rate_percent': 3.0}         a1
# 5                                                 NaN         a1
# 6                                                 NaN         a1
# 7                                  {'balance': 40000}         a1
# 8                                  {'balance': 21000}         a1
# 9                                                 NaN         a1
# 10                                                NaN         a1
# 11                     {'interest_rate_percent': 1.5}         a1
# 12                                                NaN         a1
# 13                                                NaN         a1
# 14                     {'interest_rate_percent': 4.0}         a1
# 15                                                NaN         a1
# 16                                 {'balance': 33000}         a1
# 17                                                NaN         a1
# 18                                                NaN         a1
# 19                                                NaN         a1
# 20                                                NaN         a1

# %%
vol_transact = transaction.groupby(by=["ts_transaction"], axis=0,dropna=True)["account_id"].size().reset_index(name='transaction_count')

# %%
sum(vol_transact["transaction_count"].to_list())
# Out:
# 17

# %%
data[["ts_account", "ts", "ts_card","ts_transaction","data_account","data_card","data"]]
# Out:
#             ts_account                  ts             ts_card  \
# 0  2020-01-01 14:30:00                 NaT                 NaT
# 1  2020-01-01 15:00:00                 NaT                 NaT
# 2  2020-01-01 22:00:00 2020-01-01 22:00:00                 NaT
# 3  2020-01-01 22:00:00 2020-01-02 16:00:00                 NaT
# 4  2020-01-01 22:00:00 2020-01-05 00:31:00                 NaT
# 5  2020-01-01 22:00:00 2020-01-10 16:30:00                 NaT
# 6  2020-01-01 22:00:00 2020-01-10 18:00:00                 NaT
# 7  2020-01-01 22:00:00 2020-01-15 16:01:00                 NaT
# 8  2020-01-01 22:00:00 2020-01-18 05:01:00                 NaT
# 9  2020-01-01 22:00:00 2020-01-20 14:30:00                 NaT
# 10 2020-01-01 23:00:00                 NaT                 NaT
# 11 2020-01-02 08:00:00                 NaT 2020-01-02 08:00:00
# 12 2020-01-02 08:00:00                 NaT 2020-01-05 00:30:00
# 13 2020-01-02 08:00:00                 NaT 2020-01-06 19:30:00
# 14 2020-01-02 08:00:00                 NaT 2020-01-08 01:00:00
# 15 2020-01-02 08:00:00                 NaT 2020-01-10 18:00:00
# 16 2020-01-02 08:00:00                 NaT 2020-01-15 16:00:00
# 17 2020-01-15 16:01:00                 NaT                 NaT
# 18 2020-01-16 15:30:00                 NaT 2020-01-16 15:30:00
# 19 2020-01-16 15:30:00                 NaT 2020-01-18 05:00:00
# 20 2020-01-16 15:30:00                 NaT 2020-01-18 22:30:00
#
#         ts_transaction                                       data_account  \
# 0                  NaT  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 1                  NaT                       {'phone_number': '87654321'}
# 2  2020-01-01 22:00:00                      {'savings_account_id': 'sa1'}
# 3  2020-01-02 16:00:00                      {'savings_account_id': 'sa1'}
# 4  2020-01-05 00:31:00                      {'savings_account_id': 'sa1'}
# 5  2020-01-10 16:30:00                      {'savings_account_id': 'sa1'}
# 6  2020-01-10 18:00:00                      {'savings_account_id': 'sa1'}
# 7  2020-01-15 16:01:00                      {'savings_account_id': 'sa1'}
# 8  2020-01-18 05:01:00                      {'savings_account_id': 'sa1'}
# 9  2020-01-20 14:30:00                      {'savings_account_id': 'sa1'}
# 10                 NaT  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 11 2020-01-02 08:00:00                                  {'card_id': 'c1'}
# 12 2020-01-05 00:30:00                                  {'card_id': 'c1'}
# 13 2020-01-06 19:30:00                                  {'card_id': 'c1'}
# 14 2020-01-08 01:00:00                                  {'card_id': 'c1'}
# 15 2020-01-10 18:00:00                                  {'card_id': 'c1'}
# 16 2020-01-15 16:00:00                                  {'card_id': 'c1'}
# 17                 NaT                                    {'card_id': ''}
# 18 2020-01-16 15:30:00                                  {'card_id': 'c2'}
# 19 2020-01-18 05:00:00                                  {'card_id': 'c2'}
# 20 2020-01-18 22:30:00                                  {'card_id': 'c2'}
#
#                                             data_card  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'card_id': 'c1', 'card_number': '11112222', '...
# 12                               {'status': 'ACTIVE'}
# 13                             {'credit_used': 12000}
# 14                             {'credit_used': 19000}
# 15                                 {'credit_used': 0}
# 16                               {'status': 'CLOSED'}
# 17                                                NaN
# 18  {'card_id': 'c2', 'card_number': '12123434', '...
# 19                               {'status': 'ACTIVE'}
# 20                             {'credit_used': 37000}
#
#                                                  data
# 0                                                 NaN
# 1                                                 NaN
# 2   {'savings_account_id': 'sa1', 'balance': 0, 'i...
# 3                                  {'balance': 15000}
# 4                      {'interest_rate_percent': 3.0}
# 5                                  {'balance': 40000}
# 6                                  {'balance': 21000}
# 7                      {'interest_rate_percent': 1.5}
# 8                      {'interest_rate_percent': 4.0}
# 9                                  {'balance': 33000}
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN

# %%
data["transaction_ts"] = data.apply (lambda row: row["ts"] if not pd.isnull(row["ts"]) else row["ts_card"], axis=1)

# %%
denom_account_card_df = join_table(data["accounts"]["data"], 
                                       data["cards"]["data"],
                                       "card_id", "card_id","left",
                                       suffix=("_account","_card"))

# %%
denom_account_card_df
# Out:
#     id_account op_account          ts_account  \
# 0   a1globalid          c 2020-01-01 14:30:00
# 1   a1globalid          u 2020-01-01 15:00:00
# 2   a1globalid          u 2020-01-01 22:00:00
# 3   a1globalid          u 2020-01-01 23:00:00
# 4   a1globalid          u 2020-01-02 08:00:00
# 5   a1globalid          u 2020-01-02 08:00:00
# 6   a1globalid          u 2020-01-02 08:00:00
# 7   a1globalid          u 2020-01-02 08:00:00
# 8   a1globalid          u 2020-01-02 08:00:00
# 9   a1globalid          u 2020-01-02 08:00:00
# 10  a1globalid          u 2020-01-15 16:01:00
# 11  a1globalid          u 2020-01-16 15:30:00
# 12  a1globalid          u 2020-01-16 15:30:00
# 13  a1globalid          u 2020-01-16 15:30:00
#
#                                          data_account account_id     name  \
# 0   {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1                        {'phone_number': '87654321'}         a1      NaN
# 2                       {'savings_account_id': 'sa1'}         a1      NaN
# 3   {'address': 'Jakarta', 'email': 'anthony@anoth...         a1      NaN
# 4                                   {'card_id': 'c1'}         a1      NaN
# 5                                   {'card_id': 'c1'}         a1      NaN
# 6                                   {'card_id': 'c1'}         a1      NaN
# 7                                   {'card_id': 'c1'}         a1      NaN
# 8                                   {'card_id': 'c1'}         a1      NaN
# 9                                   {'card_id': 'c1'}         a1      NaN
# 10                                    {'card_id': ''}         a1      NaN
# 11                                  {'card_id': 'c2'}         a1      NaN
# 12                                  {'card_id': 'c2'}         a1      NaN
# 13                                  {'card_id': 'c2'}         a1      NaN
#
#      address phone_number                    email card_id savings_account_id  \
# 0   New York     12345678     anthony@somebank.com     NaN                NaN
# 1        NaN     87654321                      NaN     NaN                NaN
# 2        NaN          NaN                      NaN     NaN                sa1
# 3    Jakarta          NaN  anthony@anotherbank.com     NaN                NaN
# 4        NaN          NaN                      NaN      c1                NaN
# 5        NaN          NaN                      NaN      c1                NaN
# 6        NaN          NaN                      NaN      c1                NaN
# 7        NaN          NaN                      NaN      c1                NaN
# 8        NaN          NaN                      NaN      c1                NaN
# 9        NaN          NaN                      NaN      c1                NaN
# 10       NaN          NaN                      NaN                        NaN
# 11       NaN          NaN                      NaN      c2                NaN
# 12       NaN          NaN                      NaN      c2                NaN
# 13       NaN          NaN                      NaN      c2                NaN
#
#        id_card op_card             ts_card  \
# 0          NaN     NaN                 NaT
# 1          NaN     NaN                 NaT
# 2          NaN     NaN                 NaT
# 3          NaN     NaN                 NaT
# 4   c1globalid       c 2020-01-02 08:00:00
# 5   c1globalid       u 2020-01-05 00:30:00
# 6   c1globalid       u 2020-01-06 19:30:00
# 7   c1globalid       u 2020-01-08 01:00:00
# 8   c1globalid       u 2020-01-10 18:00:00
# 9   c1globalid       u 2020-01-15 16:00:00
# 10         NaN     NaN                 NaT
# 11  c2globalid       c 2020-01-16 15:30:00
# 12  c2globalid       u 2020-01-18 05:00:00
# 13  c2globalid       u 2020-01-18 22:30:00
#
#                                             data_card card_number  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4   {'card_id': 'c1', 'card_number': '11112222', '...    11112222
# 5                                {'status': 'ACTIVE'}    11112222
# 6                              {'credit_used': 12000}    11112222
# 7                              {'credit_used': 19000}    11112222
# 8                                  {'credit_used': 0}    11112222
# 9                                {'status': 'CLOSED'}    11112222
# 10                                                NaN         NaN
# 11  {'card_id': 'c2', 'card_number': '12123434', '...    12123434
# 12                               {'status': 'ACTIVE'}    12123434
# 13                             {'credit_used': 37000}    12123434
#
#     credit_used  monthly_limit   status
# 0           NaN            NaN      NaN
# 1           NaN            NaN      NaN
# 2           NaN            NaN      NaN
# 3           NaN            NaN      NaN
# 4           0.0        30000.0  PENDING
# 5           NaN            NaN   ACTIVE
# 6       12000.0            NaN      NaN
# 7       19000.0            NaN      NaN
# 8           0.0            NaN      NaN
# 9           NaN            NaN   CLOSED
# 10          NaN            NaN      NaN
# 11          0.0        70000.0  PENDING
# 12          NaN            NaN   ACTIVE
# 13      37000.0            NaN      NaN

# %%
denom_account_saving_df = join_table(denom_account_card_df, 
                                       data["savings"]["data"],
                                       "savings_account_id", "savings_account_id","left",
                                       suffix=("","_saving"))

# %%
denom_account_saving_df.columns
# Out:
# Index(['id_account', 'op_account', 'ts_account', 'data_account', 'account_id',
#        'name', 'address', 'phone_number', 'email', 'card_id',
#        'savings_account_id', 'id_card', 'op_card', 'ts_card', 'data_card',
#        'card_number', 'credit_used', 'monthly_limit', 'status', 'id', 'op',
#        'ts', 'data', 'balance', 'interest_rate_percent', 'status_saving'],
#       dtype='object')

# %%
# denom_account_saving_df
data["savings"]["data"]
# Out:
#             id op                  ts  \
# 0  sa1globalid  c 2020-01-01 22:00:00
# 1  sa1globalid  u 2020-01-02 16:00:00
# 2  sa1globalid  u 2020-01-05 00:31:00
# 3  sa1globalid  u 2020-01-10 16:30:00
# 4  sa1globalid  u 2020-01-10 18:00:00
# 5  sa1globalid  u 2020-01-15 16:01:00
# 6  sa1globalid  u 2020-01-18 05:01:00
# 7  sa1globalid  u 2020-01-20 14:30:00
#
#                                                 data savings_account_id  \
# 0  {'savings_account_id': 'sa1', 'balance': 0, 'i...                sa1
# 1                                 {'balance': 15000}                sa1
# 2                     {'interest_rate_percent': 3.0}                sa1
# 3                                 {'balance': 40000}                sa1
# 4                                 {'balance': 21000}                sa1
# 5                     {'interest_rate_percent': 1.5}                sa1
# 6                     {'interest_rate_percent': 4.0}                sa1
# 7                                 {'balance': 33000}                sa1
#
#    balance  interest_rate_percent  status
# 0      0.0                    1.5  ACTIVE
# 1  15000.0                    NaN     NaN
# 2      NaN                    3.0     NaN
# 3  40000.0                    NaN     NaN
# 4  21000.0                    NaN     NaN
# 5      NaN                    1.5     NaN
# 6      NaN                    4.0     NaN
# 7  33000.0                    NaN     NaN

# %%
for key, val in data_collection.items():
    data_collection[key]["data"] = load_data(val["url"],{"ts": ts_mikro})
# Out:
# Start working  data/cards/
# Done working  data/cards/
# Start working  data/accounts/
# Done working  data/accounts/
# Start working  data/savings_accounts/
# Done working  data/savings_accounts/

# %%
data_collection["savings"]["data"]
# Out:
#             id op                  ts  \
# 0  sa1globalid  c 2020-01-01 22:00:00
# 1  sa1globalid  u 2020-01-20 14:30:00
# 2  sa1globalid  u 2020-01-02 16:00:00
# 3  sa1globalid  u 2020-01-15 16:01:00
# 4  sa1globalid  u 2020-01-10 16:30:00
# 5  sa1globalid  u 2020-01-05 00:31:00
# 6  sa1globalid  u 2020-01-10 18:00:00
# 7  sa1globalid  u 2020-01-18 05:01:00
#
#                                                 data savings_account_id  \
# 0  {'savings_account_id': 'sa1', 'balance': 0, 'i...                sa1
# 1                                 {'balance': 33000}                NaN
# 2                                 {'balance': 15000}                NaN
# 3                     {'interest_rate_percent': 1.5}                NaN
# 4                                 {'balance': 40000}                NaN
# 5                     {'interest_rate_percent': 3.0}                NaN
# 6                                 {'balance': 21000}                NaN
# 7                     {'interest_rate_percent': 4.0}                NaN
#
#    balance  interest_rate_percent  status
# 0      0.0                    1.5  ACTIVE
# 1  33000.0                    NaN     NaN
# 2  15000.0                    NaN     NaN
# 3      NaN                    1.5     NaN
# 4  40000.0                    NaN     NaN
# 5      NaN                    3.0     NaN
# 6  21000.0                    NaN     NaN
# 7      NaN                    4.0     NaN

# %%
data_collection["accounts"]["data"].sort_values(by=["ts"],ascending=[True])
# Out:
#            id op                  ts  \
# 0  a1globalid  c 2020-01-01 14:30:00
# 5  a1globalid  u 2020-01-01 15:00:00
# 6  a1globalid  u 2020-01-01 22:00:00
# 1  a1globalid  u 2020-01-01 23:00:00
# 3  a1globalid  u 2020-01-02 08:00:00
# 2  a1globalid  u 2020-01-15 16:01:00
# 4  a1globalid  u 2020-01-16 15:30:00
#
#                                                 data account_id     name  \
# 0  {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 5                       {'phone_number': '87654321'}        NaN      NaN
# 6                      {'savings_account_id': 'sa1'}        NaN      NaN
# 1  {'address': 'Jakarta', 'email': 'anthony@anoth...        NaN      NaN
# 3                                  {'card_id': 'c1'}        NaN      NaN
# 2                                    {'card_id': ''}        NaN      NaN
# 4                                  {'card_id': 'c2'}        NaN      NaN
#
#     address phone_number                    email card_id savings_account_id
# 0  New York     12345678     anthony@somebank.com     NaN                NaN
# 5       NaN     87654321                      NaN     NaN                NaN
# 6       NaN          NaN                      NaN     NaN                sa1
# 1   Jakarta          NaN  anthony@anotherbank.com     NaN                NaN
# 3       NaN          NaN                      NaN      c1                NaN
# 2       NaN          NaN                      NaN                        NaN
# 4       NaN          NaN                      NaN      c2                NaN

# %%
data_collection["cards"]["data"]
# Out:
#            id op                  ts  \
# 0  c1globalid  c 2020-01-02 08:00:00
# 1  c2globalid  c 2020-01-16 15:30:00
# 2  c2globalid  u 2020-01-18 05:00:00
# 3  c1globalid  u 2020-01-08 01:00:00
# 4  c1globalid  u 2020-01-05 00:30:00
# 5  c1globalid  u 2020-01-06 19:30:00
# 6  c2globalid  u 2020-01-18 22:30:00
# 7  c1globalid  u 2020-01-15 16:00:00
# 8  c1globalid  u 2020-01-10 18:00:00
#
#                                                 data card_id card_number  \
# 0  {'card_id': 'c1', 'card_number': '11112222', '...      c1    11112222
# 1  {'card_id': 'c2', 'card_number': '12123434', '...      c2    12123434
# 2                               {'status': 'ACTIVE'}     NaN         NaN
# 3                             {'credit_used': 19000}     NaN         NaN
# 4                               {'status': 'ACTIVE'}     NaN         NaN
# 5                             {'credit_used': 12000}     NaN         NaN
# 6                             {'credit_used': 37000}     NaN         NaN
# 7                               {'status': 'CLOSED'}     NaN         NaN
# 8                                 {'credit_used': 0}     NaN         NaN
#
#    credit_used  monthly_limit   status
# 0          0.0        30000.0  PENDING
# 1          0.0        70000.0  PENDING
# 2          NaN            NaN   ACTIVE
# 3      19000.0            NaN      NaN
# 4          NaN            NaN   ACTIVE
# 5      12000.0            NaN      NaN
# 6      37000.0            NaN      NaN
# 7          NaN            NaN   CLOSED
# 8          0.0            NaN      NaN

# %%
create_df = data_collection["savings"]["data"][data_collection["savings"]["data"]["op"] == "c"]
update_df = data_collection["savings"]["data"][data_collection["savings"]["data"]["op"] == "u"]
self_update_df = join_table(update_df,create_df[["id","savings_account_id"]],"id","id",how="left")
self_update_df = self_update_df.loc[:, ~self_update_df.columns.isin(["savings_account_id_left"])]
self_update_df.rename(columns={"savings_account_id_right":"savings_account_id"},inplace=True)
data_collection["accounts"]["data"] = pd.concat([create_df,self_update_df],axis=0).reset_index(drop=True)
# self_update_df
# Out:
#             id op                  ts                            data  \
# 0  sa1globalid  u 2020-01-20 14:30:00              {'balance': 33000}
# 1  sa1globalid  u 2020-01-02 16:00:00              {'balance': 15000}
# 2  sa1globalid  u 2020-01-15 16:01:00  {'interest_rate_percent': 1.5}
# 3  sa1globalid  u 2020-01-10 16:30:00              {'balance': 40000}
# 4  sa1globalid  u 2020-01-05 00:31:00  {'interest_rate_percent': 3.0}
# 5  sa1globalid  u 2020-01-10 18:00:00              {'balance': 21000}
# 6  sa1globalid  u 2020-01-18 05:01:00  {'interest_rate_percent': 4.0}
#
#    balance  interest_rate_percent status savings_account_id
# 0  33000.0                    NaN    NaN                sa1
# 1  15000.0                    NaN    NaN                sa1
# 2      NaN                    1.5    NaN                sa1
# 3  40000.0                    NaN    NaN                sa1
# 4      NaN                    3.0    NaN                sa1
# 5  21000.0                    NaN    NaN                sa1
# 6      NaN                    4.0    NaN                sa1

# %%
card = data_collection["accounts"]["data"]
create_card_df = card[card["op"] == "c"]
update_card_df = card[card["op"] == "u"]
self_card_df = join_table(update_card_df,create_card_df[["id","account_id"]],"id","id",how="left")
self_card_df = self_card_df.loc[:, ~self_card_df.columns.isin(["account_id_left"])]
self_card_df.rename(columns={"account_id_right":"account_id"},inplace=True)
final_df = pd.concat([create_card_df,self_card_df],axis=0).reset_index(drop=True)
final_df
# Out:
#            id op                  ts  \
# 0  a1globalid  c 2020-01-01 14:30:00
# 1  a1globalid  u 2020-01-01 23:00:00
# 2  a1globalid  u 2020-01-15 16:01:00
# 3  a1globalid  u 2020-01-02 08:00:00
# 4  a1globalid  u 2020-01-16 15:30:00
# 5  a1globalid  u 2020-01-01 15:00:00
# 6  a1globalid  u 2020-01-01 22:00:00
#
#                                                 data account_id     name  \
# 0  {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1  {'address': 'Jakarta', 'email': 'anthony@anoth...         a1      NaN
# 2                                    {'card_id': ''}         a1      NaN
# 3                                  {'card_id': 'c1'}         a1      NaN
# 4                                  {'card_id': 'c2'}         a1      NaN
# 5                       {'phone_number': '87654321'}         a1      NaN
# 6                      {'savings_account_id': 'sa1'}         a1      NaN
#
#     address phone_number                    email card_id savings_account_id
# 0  New York     12345678     anthony@somebank.com     NaN                NaN
# 1   Jakarta          NaN  anthony@anotherbank.com     NaN                NaN
# 2       NaN          NaN                      NaN                        NaN
# 3       NaN          NaN                      NaN      c1                NaN
# 4       NaN          NaN                      NaN      c2                NaN
# 5       NaN     87654321                      NaN     NaN                NaN
# 6       NaN          NaN                      NaN     NaN                sa1

# %%
card = data_collection["cards"]["data"]
create_card_df = card[card["op"] == "c"]
update_card_df = card[card["op"] == "u"]
self_card_df = join_table(update_card_df,create_card_df[["id","card_id","card_number"]],"id","id",how="left")
self_card_df = self_card_df.loc[:, ~self_card_df.columns.isin(["card_id_left","card_number_left"])]
self_card_df.rename(columns={"card_id_right":"card_id","card_number_right":"card_number"},inplace=True)
final_df = pd.concat([create_card_df,self_card_df],axis=0).reset_index(drop=True)
final_df
# Out:
#            id op                  ts  \
# 0  c1globalid  c 2020-01-02 08:00:00
# 1  c2globalid  c 2020-01-16 15:30:00
# 2  c2globalid  u 2020-01-18 05:00:00
# 3  c1globalid  u 2020-01-08 01:00:00
# 4  c1globalid  u 2020-01-05 00:30:00
# 5  c1globalid  u 2020-01-06 19:30:00
# 6  c2globalid  u 2020-01-18 22:30:00
# 7  c1globalid  u 2020-01-15 16:00:00
# 8  c1globalid  u 2020-01-10 18:00:00
#
#                                                 data card_id card_number  \
# 0  {'card_id': 'c1', 'card_number': '11112222', '...      c1    11112222
# 1  {'card_id': 'c2', 'card_number': '12123434', '...      c2    12123434
# 2                               {'status': 'ACTIVE'}      c2    12123434
# 3                             {'credit_used': 19000}      c1    11112222
# 4                               {'status': 'ACTIVE'}      c1    11112222
# 5                             {'credit_used': 12000}      c1    11112222
# 6                             {'credit_used': 37000}      c2    12123434
# 7                               {'status': 'CLOSED'}      c1    11112222
# 8                                 {'credit_used': 0}      c1    11112222
#
#    credit_used  monthly_limit   status
# 0          0.0        30000.0  PENDING
# 1          0.0        70000.0  PENDING
# 2          NaN            NaN   ACTIVE
# 3      19000.0            NaN      NaN
# 4          NaN            NaN   ACTIVE
# 5      12000.0            NaN      NaN
# 6      37000.0            NaN      NaN
# 7          NaN            NaN   CLOSED
# 8          0.0            NaN      NaN

# %%
final_df["data"].to_list()
# Out:
# [{'card_id': 'c1',
#   'card_number': '11112222',
#   'credit_used': 0,
#   'monthly_limit': 30000,
#   'status': 'PENDING'},
#  {'card_id': 'c2',
#   'card_number': '12123434',
#   'credit_used': 0,
#   'monthly_limit': 70000,
#   'status': 'PENDING'},
#  {'status': 'ACTIVE'},
#  {'credit_used': 19000},
#  {'status': 'ACTIVE'},
#  {'credit_used': 12000},
#  {'credit_used': 37000},
#  {'status': 'CLOSED'},
#  {'credit_used': 0}]

# %%
def join_table(left_df:pd.DataFrame, right_df:pd.DataFrame, 
               left_on:str,right_on:str, how:str="inner",
               suffix:tuple=('_left', '_right')) -> pd.DataFrame:
    return pd.merge(left_df,right_df,left_on=left_on,right_on=right_on,how=how,suffixes=suffix)

# %%
accounts = data["accounts"]["data"]
savings = data["savings"]["data"]
cards = data["cards"]["data"]

account_card_df = join_table(accounts, cards,"card_id", "card_id","left",suffix=("_account","_card"))
join_saving_df = join_table(account_card_df, savings,"savings_account_id", "savings_account_id","left",suffix=("","_saving"))

# %%
join_saving_df
# Out:
#     id_account op_account          ts_account  \
# 0   a1globalid          c 2020-01-01 14:30:00
# 1   a1globalid          u 2020-01-01 23:00:00
# 2   a1globalid          u 2020-01-15 16:01:00
# 3   a1globalid          u 2020-01-02 08:00:00
# 4   a1globalid          u 2020-01-02 08:00:00
# 5   a1globalid          u 2020-01-02 08:00:00
# 6   a1globalid          u 2020-01-02 08:00:00
# 7   a1globalid          u 2020-01-02 08:00:00
# 8   a1globalid          u 2020-01-02 08:00:00
# 9   a1globalid          u 2020-01-16 15:30:00
# 10  a1globalid          u 2020-01-16 15:30:00
# 11  a1globalid          u 2020-01-16 15:30:00
# 12  a1globalid          u 2020-01-01 15:00:00
# 13  a1globalid          u 2020-01-01 22:00:00
# 14  a1globalid          u 2020-01-01 22:00:00
# 15  a1globalid          u 2020-01-01 22:00:00
# 16  a1globalid          u 2020-01-01 22:00:00
# 17  a1globalid          u 2020-01-01 22:00:00
# 18  a1globalid          u 2020-01-01 22:00:00
# 19  a1globalid          u 2020-01-01 22:00:00
# 20  a1globalid          u 2020-01-01 22:00:00
#
#                                          data_account account_id     name  \
# 0   {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1   {'address': 'Jakarta', 'email': 'anthony@anoth...         a1      NaN
# 2                                     {'card_id': ''}         a1      NaN
# 3                                   {'card_id': 'c1'}         a1      NaN
# 4                                   {'card_id': 'c1'}         a1      NaN
# 5                                   {'card_id': 'c1'}         a1      NaN
# 6                                   {'card_id': 'c1'}         a1      NaN
# 7                                   {'card_id': 'c1'}         a1      NaN
# 8                                   {'card_id': 'c1'}         a1      NaN
# 9                                   {'card_id': 'c2'}         a1      NaN
# 10                                  {'card_id': 'c2'}         a1      NaN
# 11                                  {'card_id': 'c2'}         a1      NaN
# 12                       {'phone_number': '87654321'}         a1      NaN
# 13                      {'savings_account_id': 'sa1'}         a1      NaN
# 14                      {'savings_account_id': 'sa1'}         a1      NaN
# 15                      {'savings_account_id': 'sa1'}         a1      NaN
# 16                      {'savings_account_id': 'sa1'}         a1      NaN
# 17                      {'savings_account_id': 'sa1'}         a1      NaN
# 18                      {'savings_account_id': 'sa1'}         a1      NaN
# 19                      {'savings_account_id': 'sa1'}         a1      NaN
# 20                      {'savings_account_id': 'sa1'}         a1      NaN
#
#      address phone_number                    email card_id  ... credit_used  \
# 0   New York     12345678     anthony@somebank.com     NaN  ...         NaN
# 1    Jakarta          NaN  anthony@anotherbank.com     NaN  ...         NaN
# 2        NaN          NaN                      NaN          ...         NaN
# 3        NaN          NaN                      NaN      c1  ...         0.0
# 4        NaN          NaN                      NaN      c1  ...     19000.0
# 5        NaN          NaN                      NaN      c1  ...         NaN
# 6        NaN          NaN                      NaN      c1  ...     12000.0
# 7        NaN          NaN                      NaN      c1  ...         NaN
# 8        NaN          NaN                      NaN      c1  ...         0.0
# 9        NaN          NaN                      NaN      c2  ...         0.0
# 10       NaN          NaN                      NaN      c2  ...         NaN
# 11       NaN          NaN                      NaN      c2  ...     37000.0
# 12       NaN     87654321                      NaN     NaN  ...         NaN
# 13       NaN          NaN                      NaN     NaN  ...         NaN
# 14       NaN          NaN                      NaN     NaN  ...         NaN
# 15       NaN          NaN                      NaN     NaN  ...         NaN
# 16       NaN          NaN                      NaN     NaN  ...         NaN
# 17       NaN          NaN                      NaN     NaN  ...         NaN
# 18       NaN          NaN                      NaN     NaN  ...         NaN
# 19       NaN          NaN                      NaN     NaN  ...         NaN
# 20       NaN          NaN                      NaN     NaN  ...         NaN
#
#    monthly_limit   status           id   op                  ts  \
# 0            NaN      NaN          NaN  NaN                 NaT
# 1            NaN      NaN          NaN  NaN                 NaT
# 2            NaN      NaN          NaN  NaN                 NaT
# 3        30000.0  PENDING          NaN  NaN                 NaT
# 4            NaN      NaN          NaN  NaN                 NaT
# 5            NaN   ACTIVE          NaN  NaN                 NaT
# 6            NaN      NaN          NaN  NaN                 NaT
# 7            NaN   CLOSED          NaN  NaN                 NaT
# 8            NaN      NaN          NaN  NaN                 NaT
# 9        70000.0  PENDING          NaN  NaN                 NaT
# 10           NaN   ACTIVE          NaN  NaN                 NaT
# 11           NaN      NaN          NaN  NaN                 NaT
# 12           NaN      NaN          NaN  NaN                 NaT
# 13           NaN      NaN  sa1globalid    c 2020-01-01 22:00:00
# 14           NaN      NaN  sa1globalid    u 2020-01-20 14:30:00
# 15           NaN      NaN  sa1globalid    u 2020-01-02 16:00:00
# 16           NaN      NaN  sa1globalid    u 2020-01-15 16:01:00
# 17           NaN      NaN  sa1globalid    u 2020-01-10 16:30:00
# 18           NaN      NaN  sa1globalid    u 2020-01-05 00:31:00
# 19           NaN      NaN  sa1globalid    u 2020-01-10 18:00:00
# 20           NaN      NaN  sa1globalid    u 2020-01-18 05:01:00
#
#                                                  data  balance  \
# 0                                                 NaN      NaN
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13  {'savings_account_id': 'sa1', 'balance': 0, 'i...      0.0
# 14                                 {'balance': 33000}  33000.0
# 15                                 {'balance': 15000}  15000.0
# 16                     {'interest_rate_percent': 1.5}      NaN
# 17                                 {'balance': 40000}  40000.0
# 18                     {'interest_rate_percent': 3.0}      NaN
# 19                                 {'balance': 21000}  21000.0
# 20                     {'interest_rate_percent': 4.0}      NaN
#
#    interest_rate_percent status_saving
# 0                    NaN           NaN
# 1                    NaN           NaN
# 2                    NaN           NaN
# 3                    NaN           NaN
# 4                    NaN           NaN
# 5                    NaN           NaN
# 6                    NaN           NaN
# 7                    NaN           NaN
# 8                    NaN           NaN
# 9                    NaN           NaN
# 10                   NaN           NaN
# 11                   NaN           NaN
# 12                   NaN           NaN
# 13                   1.5        ACTIVE
# 14                   NaN           NaN
# 15                   NaN           NaN
# 16                   1.5           NaN
# 17                   NaN           NaN
# 18                   3.0           NaN
# 19                   NaN           NaN
# 20                   4.0           NaN
#
# [21 rows x 26 columns]

# %%
# savings.columns
a = {old:f"sav_{old}" for old in savings.columns}
print(a)
# Out:
# {'id': 'sav_id', 'op': 'sav_op', 'ts': 'sav_ts', 'data': 'sav_data', 'savings_account_id': 'sav_savings_account_id', 'balance': 'sav_balance', 'interest_rate_percent': 'sav_interest_rate_percent', 'status': 'sav_status'}

# %%
show_col = ["account_id","card_id", "data_account","data_card"]
account_card_df[show_col]
# Out:
#    account_id card_id                                       data_account  \
# 0          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 1          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 2          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 3          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 4          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 5          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 6          a1     NaN  {'account_id': 'a1', 'name': 'Anthony', 'addre...
# 7         NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 8         NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 9         NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 10        NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 11        NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 12        NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 13        NaN     NaN  {'address': 'Jakarta', 'email': 'anthony@anoth...
# 14        NaN     NaN                       {'phone_number': '87654321'}
# 15        NaN     NaN                       {'phone_number': '87654321'}
# 16        NaN     NaN                       {'phone_number': '87654321'}
# 17        NaN     NaN                       {'phone_number': '87654321'}
# 18        NaN     NaN                       {'phone_number': '87654321'}
# 19        NaN     NaN                       {'phone_number': '87654321'}
# 20        NaN     NaN                       {'phone_number': '87654321'}
# 21        NaN     NaN                      {'savings_account_id': 'sa1'}
# 22        NaN     NaN                      {'savings_account_id': 'sa1'}
# 23        NaN     NaN                      {'savings_account_id': 'sa1'}
# 24        NaN     NaN                      {'savings_account_id': 'sa1'}
# 25        NaN     NaN                      {'savings_account_id': 'sa1'}
# 26        NaN     NaN                      {'savings_account_id': 'sa1'}
# 27        NaN     NaN                      {'savings_account_id': 'sa1'}
# 28        NaN      c1                                  {'card_id': 'c1'}
# 29        NaN      c2                                  {'card_id': 'c2'}
#
#                                             data_card
# 0                                {'status': 'ACTIVE'}
# 1                              {'credit_used': 19000}
# 2                                {'status': 'ACTIVE'}
# 3                              {'credit_used': 12000}
# 4                              {'credit_used': 37000}
# 5                                {'status': 'CLOSED'}
# 6                                  {'credit_used': 0}
# 7                                {'status': 'ACTIVE'}
# 8                              {'credit_used': 19000}
# 9                                {'status': 'ACTIVE'}
# 10                             {'credit_used': 12000}
# 11                             {'credit_used': 37000}
# 12                               {'status': 'CLOSED'}
# 13                                 {'credit_used': 0}
# 14                               {'status': 'ACTIVE'}
# 15                             {'credit_used': 19000}
# 16                               {'status': 'ACTIVE'}
# 17                             {'credit_used': 12000}
# 18                             {'credit_used': 37000}
# 19                               {'status': 'CLOSED'}
# 20                                 {'credit_used': 0}
# 21                               {'status': 'ACTIVE'}
# 22                             {'credit_used': 19000}
# 23                               {'status': 'ACTIVE'}
# 24                             {'credit_used': 12000}
# 25                             {'credit_used': 37000}
# 26                               {'status': 'CLOSED'}
# 27                                 {'credit_used': 0}
# 28  {'card_id': 'c1', 'card_number': '11112222', '...
# 29  {'card_id': 'c2', 'card_number': '12123434', '...

# %%
join_saving_df.head()
# Out:
#    id_account op_account          ts_account  \
# 0  a1globalid          c 2020-01-01 14:30:00
# 1  a1globalid          u 2020-01-01 23:00:00
# 2  a1globalid          u 2020-01-15 16:01:00
# 3  a1globalid          u 2020-01-02 08:00:00
# 4  a1globalid          u 2020-01-16 15:30:00
#
#                                         data_account account_id     name  \
# 0  {'account_id': 'a1', 'name': 'Anthony', 'addre...         a1  Anthony
# 1  {'address': 'Jakarta', 'email': 'anthony@anoth...         a1  Anthony
# 2                                    {'card_id': ''}         a1  Anthony
# 3                                  {'card_id': 'c1'}         a1  Anthony
# 4                                  {'card_id': 'c2'}         a1  Anthony
#
#     address phone_number                    email card_id  ... credit_used  \
# 0  New York     12345678     anthony@somebank.com     NaN  ...         NaN
# 1   Jakarta     12345678  anthony@anotherbank.com     NaN  ...         NaN
# 2   Jakarta     12345678  anthony@anotherbank.com          ...         NaN
# 3   Jakarta     12345678  anthony@anotherbank.com      c1  ...         0.0
# 4   Jakarta     12345678  anthony@anotherbank.com      c2  ...         0.0
#
#   monthly_limit   status   id   op  ts  data  balance interest_rate_percent  \
# 0           NaN      NaN  NaN  NaN NaT   NaN      NaN                   NaN
# 1           NaN      NaN  NaN  NaN NaT   NaN      NaN                   NaN
# 2           NaN      NaN  NaN  NaN NaT   NaN      NaN                   NaN
# 3       30000.0  PENDING  NaN  NaN NaT   NaN      NaN                   NaN
# 4       70000.0  PENDING  NaN  NaN NaT   NaN      NaN                   NaN
#
#   status_saving
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 26 columns]

# %%
join_saving_df.to_excel("final.xlsx", index=False)

# %%
join_saving_df.columns,len(join_saving_df.columns)
# Out:
# (Index(['id_account', 'op_account', 'ts_account', 'data_account', 'account_id',
#         'name', 'address', 'phone_number', 'email', 'card_id',
#         'savings_account_id', 'id_card', 'op_card', 'ts_card', 'data_card',
#         'card_number', 'credit_used', 'monthly_limit', 'status', 'id', 'op',
#         'ts', 'data', 'balance', 'interest_rate_percent', 'status_saving'],
#        dtype='object'),
#  26)

# %%
show_col = ["id_account", "account_id","id_card", "savings_account_id","op_account","op_card","ts_account","ts_card","name","email"]
